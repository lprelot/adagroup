# %%
import requests
import pandas as pd
import numpy as np
from pylab import rcParams
import matplotlib.pyplot as plt
from IPython.display import display
from bs4 import BeautifulSoup
from Visualization.visualization import pretty_bar
import re
from requests_futures.sessions import FuturesSession
import datetime
import seaborn as sns
sns.set_context('notebook')
sns.set()

# %%
TOP_UNI_URL = "https://www.topuniversities.com"
start = datetime.datetime.now()

# %%
r = requests.get('https://www.topuniversities.com/sites/default/files/qs-rankings-data/357051_indicators.txt')
json = r.json()['data']
#print(json)

# %%
def getLink(x):
    soup = BeautifulSoup(x, 'html.parser')
    link = soup.find("a")
    return pd.Series([TOP_UNI_URL + link.get("href"),link.text],index = ['url','name'])

# %%
df = pd.DataFrame(json)
df = df[['region','overall_rank','location','uni']]
df_temp = df.apply(lambda x: getLink(x['uni']),axis = 1)
df = df.drop('uni',1)
df = df.join(df_temp)

display(df)
# Out:
#             region overall_rank        location  \
# 0    North America            1   United States
# 1    North America            2   United States
# 2    North America            3   United States
# 3    North America            4   United States
# 4           Europe            5  United Kingdom
# 5           Europe            6  United Kingdom
# 6           Europe            7  United Kingdom
# 7           Europe            8  United Kingdom
# 8    North America            9   United States
# 9           Europe           10     Switzerland
# 10            Asia           11       Singapore
# 11          Europe           12     Switzerland
# 12   North America           13   United States
# 13   North America           14   United States
# 14            Asia           15       Singapore
# 15   North America           16   United States
# 16   North America           17   United States
# 17   North America           18   United States
# 18   North America           19   United States
# 19         Oceania           20       Australia
# 20   North America           21   United States
# 21   North America           21   United States
# 22          Europe           23  United Kingdom
# 23          Europe           23  United Kingdom
# 24            Asia           25           China
# 25            Asia           26       Hong Kong
# 26   North America           27   United States
# 27   North America           28   United States
# 28            Asia           28           Japan
# 29            Asia           30       Hong Kong
# ..             ...          ...             ...
# 950         Africa          951    South Africa
# 951         Europe          952          Poland
# 952         Europe          953          France
# 953  North America          954   United States
# 954         Europe          955           Italy
# 955         Europe          956          Russia
# 956         Europe          957       Lithuania
# 957         Europe          958         Romania
# 958         Europe          959          Poland
# 959  North America          960   United States
# 960         Europe          961          Norway
# 961           Asia          962     South Korea
# 962         Europe          963         Denmark
# 963         Europe          964  United Kingdom
# 964         Europe          965          France
# 965         Europe          966          France
# 966         Europe          967         Germany
# 967         Europe          968          France
# 968         Europe          969          France
# 969           Asia          970           India
# 970         Europe          971          Sweden
# 971           Asia          972    Saudi Arabia
# 972         Europe          973  United Kingdom
# 973         Europe          974          Sweden
# 974         Europe          975           Italy
# 975         Europe          976          France
# 976  North America          977   United States
# 977         Europe          978  Czech Republic
# 978           Asia          979          Israel
# 979         Europe          980         Germany
#
#                                                    url  \
# 0    https://www.topuniversities.com/universities/m...
# 1    https://www.topuniversities.com/universities/s...
# 2    https://www.topuniversities.com/universities/h...
# 3    https://www.topuniversities.com/universities/c...
# 4    https://www.topuniversities.com/universities/u...
# 5    https://www.topuniversities.com/universities/u...
# 6    https://www.topuniversities.com/universities/u...
# 7    https://www.topuniversities.com/universities/i...
# 8    https://www.topuniversities.com/universities/u...
# 9    https://www.topuniversities.com/universities/e...
# 11     Ecole Polytechnique Fédérale de Lausanne (EPFL)
# 12                                Princeton University
# 13                                  Cornell University
# 14              National University of Singapore (NUS)
# 15                                     Yale University
# 16                            Johns Hopkins University
# 17                                 Columbia University
# 18                          University of Pennsylvania
# 19                  The Australian National University
# 20                                     Duke University
# 21                              University of Michigan
# 22                               King's College London
# 23                         The University of Edinburgh
# 24                                 Tsinghua University
# 25                         The University of Hong Kong
# 26            University of California, Berkeley (UCB)
# 27                             Northwestern University
# 28                             The University of Tokyo
# 29   The Hong Kong University of Science and Techno...
# ..                                                 ...
# 950                     University of the Western Cape
# 951                              University of Wroclaw
# 952                Université de Toulouse II-Le Mirail
# 953                              Utah State University
# 954                                  Verona University
# 955                          Voronezh State University
# 956                         Vytautas Magnus University
# 957  Universitatea de Vest din Timisoara /  West Un...
# 958                   Wroclaw University of Technology
# 959                         Baylor College of Medicine
# 960                       BI Norwegian Business School
# 961                         Chung-Ang University (CAU)
# 962                         Copenhagen Business School
# 963                               Cranfield University
# 964                                ESCP Europe - Paris
# 965                              ESSEC Business School
# 966                                EBS Business School
# 967                     HEC Paris School of Management
# 968                                             INSEAD
# 969                        Jawaharlal Nehru University
# 970                              Karolinska Institutet
# 971   King Abdullah University of Science & Technology
# 972                             London Business School
# 973                      Stockholm School of Economics
# 974                                 Bocconi University
# 975       Université de Technologie de Compiègne (UTC)
# 976            University of California, San Francisco
# 977                    University of Economics, Prague
# 978                      Weizmann Institute of Science
# 979           WHU - Otto Beisheim School of Management
#
# [980 rows x 5 columns]

# %%
def find_number(soup, list_dict_div):
    current_soup = soup
    for dict_div in list_dict_div:
        current_soup = current_soup.find("div",dict_div)
        if(current_soup is None):
            return 0
    return int(current_soup.text.replace(",", ""))

# %%
def getExtraData(x):
    #print(x)
    #r_t = requests.get(x)
    soup = BeautifulSoup(x.text, 'html.parser')

    total_faculty_int = find_number(soup, [{ "class" : "faculty-main wrapper col-md-4" },{ "class" : "total faculty"}, { "class" : "number"}])
    inter_faculty_int = find_number(soup, [{ "class" : "faculty-main wrapper col-md-4" },{ "class" : "inter faculty"}, { "class" : "number"}])
    number_students_int = find_number(soup, [{"class": "students-main wrapper col-md-4"}, { "class" : "number"}])
    international_students_int = find_number(soup, [{"class": "int-students-main wrapper col-md-4"}, { "class" : "number"}])

    return pd.DataFrame(data = [[total_faculty_int,inter_faculty_int,number_students_int,international_students_int]], columns = ['total faculty','international faculty','number of students','international students'])

def async_getExtraData(sess,x):
    return getExtraData(x)

# %%
df = df.head(200)

df_temp = df[['url']]

#display(df_temp)
urls = df_temp.values.tolist()
urls = [item for sublist in urls for item in sublist]
#print(urls)

session = FuturesSession(max_workers=10)
futures = []
results =[]

for url in urls:
    future = session.get(url)
    futures.append((url,future))

for url,r in futures:
    results.append((url,r.result()))

# %%
list_dataframe = []

for url,result in results:
    list_dataframe.append(pd.concat([getExtraData(result),pd.DataFrame(data = [url],columns=['url'])],axis = 1))
    
print('done')
# Out:
# done

# %%
df_temp = pd.concat(list_dataframe)
display(df_temp)
# Out:
#     total faculty  international faculty  number of students  \
# 0            2982                   1679               11067
# 0            4285                   2042               15878
# 0            4350                   1311               22429
# 0             953                    350                2255
# 0            5490                   2278               18770
# 0            6750                   2964               19720
# 0            6345                   2554               31080
# 0            3930                   2071               16090
# 0            2449                    635               13557
# 0            2477                   1886               19815
# 0            4338                   2993               25738
# 0            1695                   1300               10343
# 189           Asia          190           India
# 190         Africa          191    South Africa
# 191           Asia          192           Japan
# 192         Europe          192           Italy
# 193         Europe          192           Italy
# 194         Europe          195          Sweden
# 195         Europe          281         Germany
# 196  North America          195   United States
# 197         Europe          195           Spain
# 198  Latin America          199          Mexico
# 199         Europe          200     Netherlands
#
#                                                   name  total faculty  \
# 0         Massachusetts Institute of Technology (MIT)            2982
# 1                                  Stanford University           4285
# 2                                   Harvard University           4350
# 3         California Institute of Technology (Caltech)            953
# 4                              University of Cambridge           5490
# 5                                 University of Oxford           6750
# 6                      UCL (University College London)           6345
# 7                              Imperial College London           3930
# 8                                University of Chicago           2449
# 9    ETH Zurich - Swiss Federal Institute of Techno...           2477
# 10   Nanyang Technological University, Singapore (NTU)           4338
# 11     Ecole Polytechnique Fédérale de Lausanne (EPFL)           1695
# 12                                Princeton University           1007
# 13                                  Cornell University           2718
# 14              National University of Singapore (NUS)           5106
# 15                                     Yale University           4940
# 16                            Johns Hopkins University           4462
# 17                                 Columbia University           6189
# 18                          University of Pennsylvania           5499
# 19                  The Australian National University           1600
# 20                                     Duke University           2938
# 21                              University of Michigan           6809
# 22                               King's College London           3650
# 23                         The University of Edinburgh           4075
# 24                                 Tsinghua University           5506
# 25                         The University of Hong Kong           3012
# 26            University of California, Berkeley (UCB)           3321
# 27                             Northwestern University           4231
# 28                             The University of Tokyo           4514
# 29   The Hong Kong University of Science and Techno...           1150
# ..                                                 ...            ...
# 170               Albert-Ludwigs-Universitaet Freiburg           1966
# 171        Indian Institute of Technology Delhi (IITD)            466
# 172       King Fahd University of Petroleum & Minerals           1062
# 173                            University of Liverpool           2390
# 174                             University of Virginia           2509
# 175                    University of Technology Sydney           1328
# 176                                    CentraleSupélec            529
# 177                              University of Florida           5419
# 178       Indian Institute of Technology Bombay (IITB)            876
# 179                               University of Twente            910
# 180                            University of Göttingen           3678
# 181                    Vienna University of Technology            706
# 182        Universidade Estadual de Campinas (Unicamp)           1968
# 183                     University of Colorado Boulder           3685
# 184                   Vrije Universiteit Brussel (VUB)           1792
# 185                            University of Rochester           2569
# 186                     Universidad Autónoma de Madrid           2738
# 187       Alma Mater Studiorum - University of Bologna           2990
# 188                              University of Reading           1280
# 189       Indian Institute of Science (IISc) Bangalore            423
# 190                            University of Cape Town           1733
# 191                           Keio University CEMS MIM           3905
# 192                   Scuola Normale Superiore di Pisa             86
# 193  Scuola Superiore Sant'Anna Pisa di Studi Unive...            119
# 194                               Stockholm University           2154
# 195                     Technische Universität Dresden           4913
# 196                               Texas A&M University           3446
# 197                  Universitat Autònoma de Barcelona           2187
# 198  Instituto Tecnológico y de Estudios Superiores...           1822
# 199                             Maastricht University            1277
#
#      international faculty  number of students  international students
# 0                     1679               11067                    3717
# 1                     2042               15878                    3611
# 2                     1311               22429                    5266
# 3                      350                2255                     647
# 4                     2278               18770                    6699
# 5                     2964               19720                    7353
# 6                     2554               31080                   14854
# 7                     2071               16090                    8746
# 8                      635               13557                    3379
# 9                     1886               19815                    7563
# 10                    2993               25738                    7251
# 11                    1300               10343                    5896
# 12                     246                8069                    1793
# 13                     970               21904                    5411
# 14                    3086               32728                    8917
# 15                    1708               12402                    2469
# 16                    1061               16146                    4105
# 17                     913               25045                    8105
# 18                    1383               20639                    4250
# 19                     927               14442                    5551
# 20                     226               15320                    2864
# 21                    1920               43147                    7527
# 22                    1513               23780                    9451
# 23                    1553               28040                   10551
# 24                     932               36300                    4072
# 25                    2085               20214                    8230
# 26                    1395               36703                    6086
# 27                    1141               18675                    3422
# 28                     254               27279                    2639
# 29                     835               10375                    2921
# ..                     ...                 ...                     ...
# 170                    413               23214                    3897
# 171                      4                7477                      80
# 172                    665                6040                     989
# 173                    717               22065                    7502
# 174                    487               21560                    1899
# 175                    546               24207                    7769
# 176                    137                3877                    1132
# 177                    504               45485                    4597
# 178                     19                9402                      93
# 179                    299                9332                    2235
# 180                    641               30402                    3736
# 181                    172               17479                    5199
# 182                    109               26572                     966
# 183                    566               30219                    2679
# 184                    515                9284                    1853
# 185                    488                9636                    2805
# 186                    181               26511                    2976
# 187                    153               63399                    4195
# 188                    422               13330                    4077
# 189                      0                4071                      47
# 190                    379               19593                    3325
# 191                    261               33500                    2178
# 192                      1                 532                      48
# 193                      1                 789                     135
# 194                    646               28281                    2636
# 195                    669               34029                    4929
# 196                    206               60294                    4900
# 197                    230               31986                    3848
# 198                    821               13376                    1412
# 199                    502               16385                    8234
#
# [200 rows x 8 columns]

# %%
def display_ratio(df):
    df_ratio = df.copy()
    
    df_ratio['ratio'] = df_ratio['total faculty'] / df_ratio['number of students']
    df_ratio = df_ratio.sort_values('ratio',ascending=False)
    r1 = df_ratio.copy()
    
    df_ratio['ratio'] = df_ratio['international students'] / df_ratio['number of students']
    df_ratio = df_ratio.sort_values('ratio',ascending=False)
    r2 = df_ratio.copy()
    
    return r1, r2

# %% [markdown]
# ### a ,b)

# %%
r1, r2 = display_ratio(df)
pretty_bar(r1['ratio'][:10], r1['name'][:10], "Ratio between faculty members and students", "", "Ratio", figwidth=14, rot='vertical', plot_margin=3)
pretty_bar(r2['ratio'][:10], r2['name'][:10], "Ratio of international students", "", "Ratio", figwidth=14, rot='vertical', plot_margin=3)

# %% [markdown]
# ### c)

# %%
r1, r2 = display_ratio(df.groupby('location').sum().reset_index())
pretty_bar(r1['ratio'][:10], r1['location'][:10], "Ratio between faculty members and students per country", "", "Ratio", figwidth=14, rot='vertical')
pretty_bar(r2['ratio'][:10], r2['location'][:10], "Ratio of international students per country", "", "Ratio", figwidth=14, rot='vertical')

# %% [markdown]
# ### d)

# %%
r1, r2 = display_ratio(df.groupby('region').sum().reset_index())

pretty_bar(r1['ratio'][:10], r1['region'][:10], "Ratio between faculty members and students per region", "", "Ratio", figwidth=14, rot='vertical')
pretty_bar(r2['ratio'][:10], r2['region'][:10], "Ratio of international students per region", "", "Ratio", figwidth=14, rot='vertical')

# %%
end = datetime.datetime.now()
print(end - start)
# Out:
# 0:00:52.336613
